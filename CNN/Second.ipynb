# %%
import os
import shutil
import random as rd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Dataset

# %%
healthy = os.listdir('POTATOES/healthy')
damaged = os.listdir('POTATOES/damaged')

rd.shuffle(healthy)
rd.shuffle(damaged)

print('Total healthy images:', len(healthy))
print('Total damaged images:', len(damaged))
# Out:
# Total healthy images: 327
# Total damaged images: 200

# %%
train_size = 150
test_size = 30
validation_size = 20

dataset = {
    'train': {
        'healthy': healthy[:train_size],
        'damaged': damaged[:train_size],
    },
    'test': {
        'healthy': healthy[train_size:train_size+test_size],
        'damaged': damaged[train_size:train_size+test_size],
    },
    'validation': {
        'healthy': healthy[train_size+test_size:train_size+test_size+validation_size],
        'damaged': damaged[train_size+test_size:train_size+test_size+validation_size],
    },
}

# %%
# Define root directory
src_dir = './POTATOES'
dst_dir = './dataset'


# Empry directory
if os.path.exists(dst_dir): shutil.rmtree(dst_dir)

for group in ['train', 'test', 'validation']:
    for label in ['healthy', 'damaged']:
        # Generate paths
        os.makedirs(dst_dir + '/' + group + '/' + label)
        # Create new dataset
        for filename in dataset[group][label]:
            shutil.copy(
                src_dir + '/' + label + '/' + filename,
                dst_dir + '/' + group + '/' + label + '/' + filename,
            )

# %%
# Training set with data augmentation
train_datagen = ImageDataGenerator(rescale = 1.0/255.,
                                   rotation_range = 40,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   # shear_range = 0.2,
                                   # zoom_range = 0.2,
                                   horizontal_flip = True,
                                   vertical_flip = True,
                                   fill_mode = 'nearest')

# Test set just rescaled
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

# %%
batch_size = 10
# Flow training images in batches of 10 using train_datagen generator
train_generator = train_datagen.flow_from_directory(directory=dst_dir + '/train',
                                                    class_mode='binary',
                                                    batch_size=batch_size,
                                                    target_size=(250, 250))

# Flow testing images in batches of 10 using test_datagen generator
test_generator =  train_datagen.flow_from_directory(directory=dst_dir + '/test',
                                                    class_mode  = 'binary',
                                                    batch_size=batch_size,
                                                    target_size = (250, 250))
# Out:
# Found 300 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %% [markdown]
# ## Model

# %%
model = tf.keras.models.Sequential([
    # Conv layers
    tf.keras.layers.Conv2D(8, (3,3), activation='relu', input_shape=(250,250,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten layer
    tf.keras.layers.Flatten(),
    # Fully connected layers
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    # Output neuron
    tf.keras.layers.Dense(1, activation='sigmoid'),
    #TODO tf.keras.layers.Dense(1, activation='linear') or scale parameter
])

# TODO implement dropout (~50%), too many filters, really necessary?

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 248, 248, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 124, 124, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 16)      1168
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 59, 59, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 29, 29, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 128)               1384576
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,419,473
# Trainable params: 1,419,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Training

# %%
history = model.fit(train_generator,
                    epochs=30,
                    steps_per_epoch=len(train_generator),
                    validation_data=test_generator,
                    validation_steps=len(test_generator))

#TODO callback to stop on accuracy threshold
# Out:
# Epoch 1/30
# 30/30 [==============================] - 14s 418ms/step - loss: 0.7382 - accuracy: 0.5600 - val_loss: 0.7223 - val_accuracy: 0.5000
# Epoch 2/30
# 30/30 [==============================] - 9s 310ms/step - loss: 0.6997 - accuracy: 0.6000 - val_loss: 0.6368 - val_accuracy: 0.8000
# Epoch 3/30
# 30/30 [==============================] - 9s 283ms/step - loss: 0.6906 - accuracy: 0.5867 - val_loss: 0.6066 - val_accuracy: 0.7500
# Epoch 4/30
# 30/30 [==============================] - 9s 283ms/step - loss: 0.6582 - accuracy: 0.6533 - val_loss: 0.6403 - val_accuracy: 0.6167
# Epoch 5/30
# 30/30 [==============================] - 9s 296ms/step - loss: 0.6387 - accuracy: 0.6567 - val_loss: 0.5267 - val_accuracy: 0.7500
# Epoch 6/30
# 30/30 [==============================] - 9s 287ms/step - loss: 0.6218 - accuracy: 0.6800 - val_loss: 0.4674 - val_accuracy: 0.7667
# Epoch 7/30
# 30/30 [==============================] - 9s 299ms/step - loss: 0.5813 - accuracy: 0.7167 - val_loss: 0.4252 - val_accuracy: 0.8667
# Epoch 8/30
# 30/30 [==============================] - 9s 302ms/step - loss: 0.5337 - accuracy: 0.7500 - val_loss: 0.4020 - val_accuracy: 0.7833
# Epoch 9/30
# 30/30 [==============================] - 10s 317ms/step - loss: 0.5273 - accuracy: 0.7433 - val_loss: 0.4018 - val_accuracy: 0.8333
# Epoch 10/30
# 30/30 [==============================] - 10s 336ms/step - loss: 0.5265 - accuracy: 0.7867 - val_loss: 0.9018 - val_accuracy: 0.5667
# Epoch 11/30
# 30/30 [==============================] - 11s 357ms/step - loss: 0.5545 - accuracy: 0.7467 - val_loss: 0.3910 - val_accuracy: 0.8333
# Epoch 12/30
# 30/30 [==============================] - 10s 323ms/step - loss: 0.4808 - accuracy: 0.7867 - val_loss: 0.4005 - val_accuracy: 0.8667
# Epoch 13/30
# 30/30 [==============================] - 10s 322ms/step - loss: 0.5335 - accuracy: 0.7533 - val_loss: 0.4114 - val_accuracy: 0.8500
# Epoch 14/30
# 30/30 [==============================] - 10s 316ms/step - loss: 0.4751 - accuracy: 0.7733 - val_loss: 0.4129 - val_accuracy: 0.7833
# Epoch 15/30
# 30/30 [==============================] - 10s 329ms/step - loss: 0.5244 - accuracy: 0.7233 - val_loss: 0.3930 - val_accuracy: 0.8333
# Epoch 16/30
# 30/30 [==============================] - 10s 327ms/step - loss: 0.4591 - accuracy: 0.8133 - val_loss: 0.4129 - val_accuracy: 0.8333
# Epoch 17/30
# 30/30 [==============================] - 10s 330ms/step - loss: 0.4485 - accuracy: 0.7767 - val_loss: 0.5976 - val_accuracy: 0.6667
# Epoch 18/30
# 30/30 [==============================] - 10s 327ms/step - loss: 0.4601 - accuracy: 0.7900 - val_loss: 0.4466 - val_accuracy: 0.8000
# Epoch 19/30
# 30/30 [==============================] - 10s 327ms/step - loss: 0.5373 - accuracy: 0.7467 - val_loss: 0.4031 - val_accuracy: 0.8500
# Epoch 20/30
# 30/30 [==============================] - 10s 326ms/step - loss: 0.4241 - accuracy: 0.8033 - val_loss: 0.2967 - val_accuracy: 0.8667
# Epoch 21/30
# 30/30 [==============================] - 10s 337ms/step - loss: 0.4705 - accuracy: 0.8033 - val_loss: 0.3054 - val_accuracy: 0.8500
# Epoch 22/30
# 30/30 [==============================] - 10s 322ms/step - loss: 0.4701 - accuracy: 0.7967 - val_loss: 0.3256 - val_accuracy: 0.9000
# Epoch 23/30
# 30/30 [==============================] - 10s 328ms/step - loss: 0.4625 - accuracy: 0.7867 - val_loss: 0.3109 - val_accuracy: 0.8333
# Epoch 24/30
# 30/30 [==============================] - 10s 329ms/step - loss: 0.4247 - accuracy: 0.8133 - val_loss: 0.4017 - val_accuracy: 0.7833
# Epoch 25/30
# 30/30 [==============================] - 10s 331ms/step - loss: 0.4776 - accuracy: 0.7833 - val_loss: 0.3516 - val_accuracy: 0.8500
# Epoch 26/30
# 30/30 [==============================] - 10s 336ms/step - loss: 0.4514 - accuracy: 0.8100 - val_loss: 0.3925 - val_accuracy: 0.8500
# Epoch 27/30
# 30/30 [==============================] - 9s 291ms/step - loss: 0.4140 - accuracy: 0.8200 - val_loss: 0.4599 - val_accuracy: 0.8000
# Epoch 28/30
# 30/30 [==============================] - 10s 327ms/step - loss: 0.4489 - accuracy: 0.8000 - val_loss: 0.3896 - val_accuracy: 0.8333
# Epoch 29/30
# 30/30 [==============================] - 10s 329ms/step - loss: 0.4288 - accuracy: 0.8000 - val_loss: 0.3210 - val_accuracy: 0.8167
# Epoch 30/30
# 30/30 [==============================] - 10s 327ms/step - loss: 0.4475 - accuracy: 0.7933 - val_loss: 0.3929 - val_accuracy: 0.8167

# %% [markdown]
# ## Prediction

# %%
validation_images = ['./dataset/validation/damaged/' + img for img in os.listdir('./dataset/validation/damaged')]
validation_images += ['./dataset/validation/healthy/' + img for img in os.listdir('./dataset/validation/healthy')]

path = rd.choice(validation_images)
test_img = image.load_img(path, target_size=(250,250))

plt.imshow(test_img)

x = image.img_to_array(test_img)
x /= 255
x = np.expand_dims(x, axis=0)
images = np.vstack([x])

classes = model.predict(images, batch_size=1)



print(classes[0])
print(path)
print('Healthy' if classes[0] > 0.5 else 'Damaged')
# Out:
# [0.08150929]
# ./dataset/validation/damaged/WIN_20220526_15_12_34_Pro.jpg
# Damaged

# %% [markdown]
# ## Accuracy and Loss evaluation

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.legend(['train', 'test'])
plt.title('Training and validation accuracy')
plt.show()
print("")

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# ## Save trained model

# %%
model.save_weights('./checkpoints/last_training')
